# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13086682468","type":"PushEvent","actor":{"id":65581441,"login":"bayashi-831","display_login":"bayashi-831","gravatar_id":"","url":"https://api.github.com/users/bayashi-831","avatar_url":"https://avatars.githubusercontent.com/u/65581441?"},"repo":{"id":284262263,"name":"bayashi-831/fleamarket_sample_76a","url":"https://api.github.com/repos/bayashi-831/fleamarket_sample_76a"},"payload":{"push_id":5468544134,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"03aebca4fa02b941cd0d956d5593fd15027a055b","before":"bf14f017e301a5f85ac988e3e31831bf85663966","commits":[{"sha":"03aebca4fa02b941cd0d956d5593fd15027a055b","author":{"email":"kuroneko.love.takkyubin@gmail.com","name":"bayashi-831"},"message":"s3-Introduction","distinct":true,"url":"https://api.github.com/repos/bayashi-831/fleamarket_sample_76a/commits/03aebca4fa02b941cd0d956d5593fd15027a055b"}]},"public":true,"created_at":"2020-08-02T07:40:46Z"},{"id":"13086682463","type":"PushEvent","actor":{"id":4068610,"login":"
# ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13086682468',
#   'type': 'PushEvent',
#   'actor': {'id': 65581441,
#    'login': 'bayashi-831',
#    'display_login': 'bayashi-831',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bayashi-831',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65581441?'},
#   'repo': {'id': 284262263,
#    'name': 'bayashi-831/fleamarket_sample_76a',
#    'url': 'https://api.github.com/repos/bayashi-831/fleamarket_sample_76a'},
#   'payload': {'push_id': 5468544134,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '03aebca4fa02b941cd0d956d5593fd15027a055b',
#    'before': 'bf14f017e301a5f85ac988e3e31831bf85663966',
#    'commits': [{'sha': '03aebca4fa02b941cd0d956d5593fd15027a055b',
#      'author': {'email': 'kuroneko.love.takkyubin@gmail.com',
#       'name': 'bayashi-831'},
#      'message': 's3-Introduction',
#      'distinct': True,
# ...

# %%
raw = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel' )
json.loads(raw.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
# ...
